# %% [markdown]
# # Workbook 01 — I/O Mapping
#
# **Sprint 1** — companion to Bolton Ch. 1 & 2.
#
# ## Task
#
# For each of the 10 devices below, classify:
# 1. **Type:** Discrete or Analog
# 2. **Direction:** Input (sensor) or Output (actuator)
# 3. **Signal:** 24 VDC discrete / 4–20 mA / 0–10 V / dry contact / VAC switched
# 4. **Sourcing or Sinking:** when discrete (PNP / NPN / N/A)
# 5. **Notes:** anything you'd flag to the panel-builder
#
# There's no single right answer for every row. The discussion is the point.

# %%
import pandas as pd

devices = [
    'Limit switch on guard door',
    'Inductive proximity sensor (steel parts)',
    'Photoelectric through-beam (carton presence)',
    'Pt100 RTD (oven temperature)',
    'Pressure transducer (steam header)',
    'Mushroom-head emergency stop',
    'Solenoid valve (pneumatic, 24 VDC)',
    '3-phase motor contactor (4 kW)',
    'VFD speed reference',
    'Encoder (incremental, 1024 PPR)',
]

rows = []
for d in devices:
    rows.append({
        'Device': d,
        'Type': '',          # Discrete / Analog
        'Direction': '',     # Input / Output
        'Signal': '',        # 24 VDC / 4–20 mA / 0–10 V / dry contact / VAC
        'PNP_NPN': '',       # PNP / NPN / N/A
        'Notes': '',
    })

df = pd.DataFrame(rows)
df

# %% [markdown]
# ## Reflection
#
# Pick the two devices you found hardest to classify. Write 2–3 sentences for each on what made it tricky and how you'd ask a panel-builder to clarify.

# %% [markdown]
# **Device 1:**
#
# **Device 2:**
